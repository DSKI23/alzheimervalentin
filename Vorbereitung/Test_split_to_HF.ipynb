# %% [markdown]
# <a href="https://colab.research.google.com/github/DSKI23/alzheimervalentin/blob/15-fix-datasets/Vorbereitung/Test_split_to_HF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dieses File muss nicht ausgeführt werden. Es soll nur nachvollziehbar machen wie die Daten gesplittet und auf HuggingFace hochgeladen wurden.

# %%
# !pip install --upgrade huggingface_hub
# !pip install datasets

# %%
from huggingface_hub import HfApi
from huggingface_hub import create_repo
from huggingface_hub import notebook_login
from datasets import load_dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import os

# %%
notebook_login()

# %%
dataset = load_dataset("DS23-KI-Projekt/alzheimerdataset")
dataset
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# alzheimers_prediction_dataset.csv:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/74283 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
# ...

# %%
create_repo("DS23-KI-Projekt/alzheimerdataset_split", repo_type="dataset")
'https://huggingface.co/datasets/DS23-KI-Projekt/alzheimerdataset_split'
# Out:
# 'https://huggingface.co/datasets/DS23-KI-Projekt/alzheimerdataset_split'

# %%
df = dataset['train'].to_pandas()
df.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# ...

# %%
train_test_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
print(train_test_df.shape)
print(val_df.shape)
# Out:
# (59426, 25)
# (14857, 25)

# %%
#os.mkdir('kaggle')

train_test_df.to_csv('/content/kaggle/training.csv', index=False)
val_df.to_csv('/content/kaggle/validation.csv', index=False)

# %%
api = HfApi()
api.upload_folder(
    folder_path="/content/kaggle",
    repo_id="DS23-KI-Projekt/alzheimerdataset_split",
    repo_type="dataset"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/datasets/DS23-KI-Projekt/alzheimerdataset_split/commit/dda9f85fd540003fd16a90a319b9740b2131b28c', commit_message='Upload folder using huggingface_hub', commit_description='', oid='dda9f85fd540003fd16a90a319b9740b2131b28c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/DS23-KI-Projekt/alzheimerdataset_split', endpoint='https://huggingface.co', repo_type='dataset', repo_id='DS23-KI-Projekt/alzheimerdataset_split'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Neuer Abschnitt
